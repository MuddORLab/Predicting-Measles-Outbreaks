# %%
library(readr)

# %%
#Classification model - key variables

dtree_vars <- read_csv("data/results/merged_w_svi/important_vars_dtree.csv")

rforest_vars <- read_csv("data/results/merged_w_svi/important_vars_rforest.csv")

boost_vars <- read_csv("data/results/merged_w_svi/important_vars_boost.csv")
# Out:
# Rows: 21 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): Variable
# dbl (1): Importance
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `` -> `...1`
# Rows: 234 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): ...1
# dbl (4): 0, 1, MeanDecreaseAccuracy, MeanDecreaseGini
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# New names:
# • `` -> `...1`
# Rows: 54 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): Feature
# dbl (4): ...1, Gain, Cover, Frequency
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ...

# %%
# Out:
#    Variable                                Importance
# 1  mammogram_no                            47.3890726
# 2  mammogram_yes                           47.3890726
# 3  flu_vaccine_location_doctors_office_hmo 46.9908451
# 4  any_cancer_no                           44.9997076
# 5  any_cancer_yes                          44.9997076
# 6  other_cancer_no                         44.9997076
# 7  pct_black                               15.0199203
# 8  ep_age65                                 8.8727071
# 9  cve                                      5.3773238
# 10 ep_disabl                                5.0624847
# 11 ep_twomore                               4.8451356
# 12 asthma_status_never                      3.8761085
# 13 bp_location_at_home                      3.8761085
# 14 ep_unemp                                 2.0334036
# 15 ep_noint                                 1.5040284
# 16 ep_mobile                                1.0167018
# ...
